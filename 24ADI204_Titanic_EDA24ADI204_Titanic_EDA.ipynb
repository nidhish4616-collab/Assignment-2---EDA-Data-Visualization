# %%
EDA and Data Visualization
24ADI204-Data Science and Visualization
Name:V.Nidhish
Roll Number:25BAD067
Dataset: Titanic Dataset
Source: Kaggle

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-e7be1ff2-13d9-489f-a641-ff32affdf800" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e7be1ff2-13d9-489f-a641-ff32affdf800">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("train.csv")

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Basic EDA

# %%
print("Number of rows and columns:")
print(df.shape)

print("\nColumn names:")
print(df.columns)

print("\nMissing values:")
print(df.isnull().sum())

print("\nStatistical summary:")
df.describe()
# Out:
# Number of rows and columns:
# (891, 12)
#
# Column names:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
#
# Missing values:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
#
# Statistical summary:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# ...

# %%
df["Age"] = df["Age"].fillna(df["Age"].median())
df["Fare"] = df["Fare"].fillna(df["Fare"].median())
df["Embarked"] = df["Embarked"].fillna(df["Embarked"].mode()[0])
df["FamilySize"] = df["SibSp"] + df["Parch"] + 1

# %% [markdown]
# Plot 1-Survival Count Plot

# %%
sns.countplot(data=df, x="Survived")

plt.title("Survival Count Plot")
plt.xlabel("Survived")
plt.ylabel("Number of Passengers")

plt.show()

# %% [markdown]
# Plot 2-Gender Count Plot

# %%
sns.countplot(data=df, x="Sex")

plt.title("Gender Count Plot")
plt.xlabel("Gender")
plt.ylabel("Number of Passengers")

plt.show()

# %% [markdown]
# Plot 3-Passenger Class Count Plot

# %%
sns.countplot(data=df, x="Pclass")

plt.title("Passenger Class Count Plot")
plt.xlabel("Passenger Class")
plt.ylabel("Number of Passengers")

plt.show()

# %% [markdown]
# Plot 4-Embarked Count Plot

# %%
sns.countplot(data=df, x="Embarked")

plt.title("Embarked Count Plot")
plt.xlabel("Port")
plt.ylabel("Number of Passengers")

plt.show()

# %% [markdown]
# Plot 5-Siblings/Spouses Count Plot

# %%
sns.countplot(data=df, x="SibSp")

plt.title("Siblings/Spouses Count Plot")
plt.xlabel("Number of Siblings/Spouses")
plt.ylabel("Number of Passengers")

plt.show()

# %% [markdown]
#  Plot 6-Survival by Gender Bar Plot

# %%
survival_gender = df.groupby("Sex")["Survived"].mean()

survival_gender.plot(kind="bar")

plt.title("Survival by Gender")
plt.xlabel("Gender")
plt.ylabel("Survival Rate")

plt.show()

# %% [markdown]
# Plot 7-Survival by Passenger Class Bar Plot

# %%
survival_class = df.groupby("Pclass")["Survived"].mean()

survival_class.plot(kind="bar")

plt.title("Survival by Passenger Class")
plt.xlabel("Passenger Class")
plt.ylabel("Survival Rate")

plt.show()

# %% [markdown]
# Plot 8-Age Distribution Histogram

# %%
plt.hist(df["Age"], bins=20)

plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# Plot 9-Fare Distribution Histogram

# %%
plt.hist(df["Fare"], bins=20)

plt.title("Fare Distribution")
plt.xlabel("Fare")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# Plot 10-SibSp Distribution Histogram

# %%
plt.hist(df["SibSp"], bins=8)

plt.title("SibSp Distribution")
plt.xlabel("Number of Siblings/Spouses")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
#  Plot 11-Family Size Distribution Histogram

# %%
plt.hist(df["FamilySize"], bins=10)

plt.title("Family Size Distribution")
plt.xlabel("Family Size")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# Plot 12-Age vs Fare Scatter Plot

# %%
plt.scatter(df["Age"], df["Fare"])

plt.title("Age vs Fare")
plt.xlabel("Age")
plt.ylabel("Fare")

plt.show()

# %% [markdown]
# Plot 13-Age vs Fare by Survival Scatter Plot

# %%
sns.scatterplot(data=df, x="Age", y="Fare", hue="Survived")

plt.title("Age vs Fare by Survival")
plt.xlabel("Age")
plt.ylabel("Fare")

plt.show()

# %% [markdown]
# Plot 14-Age vs Passenger Class Scatter Plot

# %%
plt.scatter(df["Age"], df["Pclass"])

plt.title("Age vs Passenger Class")
plt.xlabel("Age")
plt.ylabel("Passenger Class")

plt.show()

# %% [markdown]
# Plot 15-Age by Gender Box Plot

# %%
sns.boxplot(data=df, x="Sex", y="Age")

plt.title("Age by Gender")
plt.xlabel("Gender")
plt.ylabel("Age")

plt.show()

# %% [markdown]
# Plot 16-Age by Survival Box Plot

# %%
sns.boxplot(data=df, x="Survived", y="Age")

plt.title("Age by Survival")
plt.xlabel("Survived")
plt.ylabel("Age")

plt.show()

# %% [markdown]
# Plot 17-Fare by Passenger Class Box Plot

# %%
sns.boxplot(data=df, x="Pclass", y="Fare")

plt.title("Fare by Passenger Class")
plt.xlabel("Passenger Class")
plt.ylabel("Fare")

plt.show()

# %% [markdown]
# Plot 18-Fare by Survival Box Plot

# %%
sns.boxplot(data=df, x="Survived", y="Fare")

plt.title("Fare by Survival")
plt.xlabel("Survived")
plt.ylabel("Fare")

plt.show()

# %% [markdown]
# Plot 19-Age by Gender Violin Plot

# %%
sns.violinplot(data=df, x="Sex", y="Age")

plt.title("Age by Gender")
plt.xlabel("Gender")
plt.ylabel("Age")

plt.show()

# %% [markdown]
# Plot 20-Age by Survival Violin Plot

# %%
sns.violinplot(data=df, x="Survived", y="Age")

plt.title("Age by Survival")
plt.xlabel("Survived")
plt.ylabel("Age")

plt.show()

# %% [markdown]
# Plot 21-Fare by Passenger Class Violin Plot

# %%
sns.violinplot(data=df, x="Pclass", y="Fare")

plt.title("Fare by Passenger Class")
plt.xlabel("Passenger Class")
plt.ylabel("Fare")

plt.show()

# %% [markdown]
# Plot 22-Survival Distribution Pie Chart

# %%
survival_counts = df["Survived"].value_counts()

plt.pie(
    survival_counts,
    labels=["Did Not Survive", "Survived"],
    autopct="%1.1f%%"
)

plt.title("Survival Distribution")
plt.show()

# %% [markdown]
# Plot 23-Gender Distribution Pie Chart

# %%
gender_counts = df["Sex"].value_counts()

plt.pie(
    gender_counts,
    labels=gender_counts.index,
    autopct="%1.1f%%"
)

plt.title("Gender Distribution")
plt.show()

# %% [markdown]
# Plot 24-Passenger Class Distribution Pie Chart

# %%
class_counts = df["Pclass"].value_counts().sort_index()

plt.pie(
    class_counts,
    labels=["1st Class", "2nd Class", "3rd Class"],
    autopct="%1.1f%%"
)

plt.title("Passenger Class Distribution")
plt.show()

# %% [markdown]
# Plot 25-Correlation Heatmap

# %%
numeric_columns = [
    "Survived",
    "Pclass",
    "Age",
    "SibSp",
    "Parch",
    "Fare",
    "FamilySize"
]

correlation = df[numeric_columns].corr()

sns.heatmap(correlation, annot=True, cmap="coolwarm", fmt=".2f")

plt.title("Correlation Heatmap")
plt.show()

# %%
df["AgeGroup"] = pd.cut(
    df["Age"],
    bins=[0, 10, 20, 30, 40, 50, 60, 70, 100],
    labels=["0-10", "11-20", "21-30", "31-40",
            "41-50", "51-60", "61-70", "71+"]
)

# %% [markdown]
# Plot 26-Average Fare by Age Group Line Plot

# %%
average_fare = df.groupby(
    "AgeGroup",
    observed=False
)["Fare"].mean()

plt.plot(
    average_fare.index.astype(str),
    average_fare.values,
    marker="o"
)

plt.title("Average Fare by Age Group")
plt.xlabel("Age Group")
plt.ylabel("Average Fare")

plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# Plot 27-Survival Rate by Age Group Line Plot

# %%
survival_rate = df.groupby(
    "AgeGroup",
    observed=False
)["Survived"].mean()

plt.plot(
    survival_rate.index.astype(str),
    survival_rate.values,
    marker="o"
)

plt.title("Survival Rate by Age Group")
plt.xlabel("Age Group")
plt.ylabel("Survival Rate")

plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# Plot 28-Age vs Passenger Class Strip Plot

# %%
sns.stripplot(data=df, x="Pclass", y="Age")

plt.title("Age vs Passenger Class")
plt.xlabel("Passenger Class")
plt.ylabel("Age")

plt.show()

# %% [markdown]
# Plot 29-Fare vs Gender Strip Plot

# %%
sns.stripplot(data=df, x="Sex", y="Fare")

plt.title("Fare vs Gender")
plt.xlabel("Gender")
plt.ylabel("Fare")

plt.show()

# %% [markdown]
# Plot 30-Age vs Survival Strip Plot

# %%
sns.stripplot(data=df, x="Survived", y="Age")

plt.title("Age vs Survival")
plt.xlabel("Survived")
plt.ylabel("Age")

plt.show()
